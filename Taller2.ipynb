# %% [markdown]
# **Taller 1 y 2**

# %%
Num_identificacion = input("1. Digite su documento ")
Nombres = input("2. Digite sus nombres ")
Apellidos = input("3. Digite sus apellidos ")
Direccion = input("4. Digite su dirección ")
Telefono = input("5. Digite su telefono ")
Edad = int(input("6. Cual es su edad "))
Estado_C = input("7. En que estado civil se encuentra ")
Sueldo = float(input("8. Cual es su sueldo basico "))
Dias_Tr= int(input("9. Cuantos dias trabajo "))
Fecha = input("10. Cual fue su fecha de contratacion (escribala en el formato (Día/mes/año) ")
Num_hijos = int(input("11. cuantos hijos tiene "))
print("\nEl documento es "+ Num_identificacion)
print("\nEl nombre es "+ Nombres) 
print("\nLos apellidos son "+ Apellidos)
print("\nLa direccion es "+ Direccion)
print("\nEl telefono es" + Telefono)
print(f"\nLa edad  es {Edad}" )
print("\nLa fecha de contratacion es " + Fecha)

# Condicional para bono prepension
if Edad > 55:
  bono = Sueldo * 1.05
  print(f"\nel sueldo mas el bono del 5% de prepension es de ${bono:,.0f}")
else:
 print(f"\nEl sueldo ingresado es ${Sueldo:,.0f}")
 print(f"\nLa edad  es {Edad}")

# Condicional de vacaciones de empleado casado
if Estado_C == "casado" and Num_hijos > 0:
   print(f"\ntienes unas vacaciones que se otorgaran en diciembre")
else:
  print(f"\nEl estado civil que se ingreso fue {Estado_C}")
  print(f"\nEl numero de hijos es {Num_hijos}")

#condicion para la comsion del suelo al 2 o 5%
if Sueldo >= 1000000 and Sueldo <= 1500000:
  com_dos = Sueldo * 1.02
  print(f"\n Su sueldo mas comision de 2% es ${com_dos:,.0f}")
elif Sueldo >= 1500001 and Sueldo <= 2000000:
  com_cinco =Sueldo * 1.05
  print(f"\n Su sueldo mas comision de 5% es ${com_cinco:,.0f}")
else:
  print(f"\n el sueldo ingresado es ${Sueldo:,.0f}")

#
if Dias_Tr > 20 and Sueldo <1000000:
  print(f"\n como trabajo {Dias_Tr}Tiene derecho a un bono de alimentacion ")
else:
  print(f"\n Los dias trabajados son {Dias_Tr} ")
# Out:
# 1. Digite su documento 123412
# 2. Digite sus nombres jhon esteban
# 3. Digite sus apellidos dsgfdbfs
# 4. Digite su dirección casdq3
# 5. Digite su telefono 2312412
# 6. Cual es su edad 55
# 7. En que estado civil se encuentra casado
# 8. Cual es su sueldo basico 1600000
# 9. Cuantos dias trabajo 25
# 10. Cual fue su fecha de contratacion (escribala en el formato (Día/mes/año) 12
# 11. cuantos hijos tiene 2
#
# El documento es 123412
#
# El nombre es jhon esteban
#
# Los apellidos son dsgfdbfs
#
# La direccion es casdq3
#
# El telefono es2312412
#
# La edad  es 55
#
# La fecha de contratacion es 12
#
# El sueldo ingresado es $1,600,000
#
# La edad  es 55
#
# tienes unas vacaciones que se otorgaran en diciembre
#
#  Su sueldo mas comision de 5% es $1,680,000
#
#  Los dias trabajados son 25
